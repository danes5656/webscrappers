# %%
#wiki package
import wikipedia

#webdrivers
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

from selenium.webdriver.edge.service import Service
from selenium.webdriver.edge.options import Options

import os

service = Service(verbose = True)
options = Options()
options.add_argument("headless")

root = r'/Users/eduardotorres/Documents'
sl = r'/'
base_location = ''.join(
    [root, sl, r'GitHub/python-development/personal-projects/nba-predictions'])
add_ins = ''.join([root, sl, r'stuff'])
os.chdir(add_ins)
print(os.getcwd())

executable_chrome = ''.join([add_ins, sl, r'msedgedriver'])
driver = webdriver.Edge(service = service, options=options, executable_path=executable_chrome)

def chatbot_response(query):
    try:
        driver.get(f'https://www.google.com/search?q='+ query +'&hl=en')
        content = driver.find_element(by=By.CLASS_NAME,value="xpdopen").get_attribute("innerText")
        response = content.split("\n")[1]
    except:
        try:
            #try investopedia
            query = query.lower().split()[-1]
            letter = query[0]
            if "/" in query:
                query = query.replace("/", "-").replace(" ", "").replace("%", "").replace("(", "").replace(")", "").replace("?", "")
            driver.get(f'https://www.investopedia.com/terms/'+letter+'/'+query+'.asp')
            response = driver.find_element(By.ID,"mntl-sc-block_1-0-1").get_attribute("innerText")
        except:
        #define wikipedia intention
            if query.lower() in ('evs', 'evalueserve'):
                response = "Evalueserve is a global company specializing in research, analysis and data management services"
            else:
                try:
                    mercury = wikipedia.summary(wikipedia.search(query)[0], auto_suggest=False)
                    response = mercury.split('.')[0]
                except wikipedia.exceptions.DisambiguationError as e:
                    options = listToStr = ', '.join([str(elem) for elem in e.options])    
                    response = "I was unable to find what you are looking for in wikipwdia, try with " + options
    return response

#driver.quit()
# Out:
# /Users/eduardotorres/Documents/stuff
# /var/folders/yb/5s627cbj3pb306p1y5pv9_rr0000gn/T/ipykernel_12377/4016571421.py:27: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(service = service, options=options, executable_path=executable_chrome)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/miniforge3/envs/forge_webscrap/lib/python3.10/site-packages/selenium/webdriver/common/service.py:71, in Service.start(self)
#      70     cmd.extend(self.command_line_args())
# ---> 71     self.process = subprocess.Popen(cmd, env=self.env,
#      72                                     close_fds=system() != 'Windows',
#      73                                     stdout=self.log_file,
#      74                                     stderr=self.log_file,
#      75                                     stdin=PIPE,
#      76                                     creationflags=self.creationflags)
#      77 except TypeError:
#
# File ~/miniforge3/envs/forge_webscrap/lib/python3.10/subprocess.py:969, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#     966             self.stderr = io.TextIOWrapper(self.stderr,
#     967                     encoding=encoding, errors=errors)
# --> 969     self._execute_child(args, executable, preexec_fn, close_fds,
#     970                         pass_fds, cwd, env,
#     971                         startupinfo, creationflags, shell,
#     972                         p2cread, p2cwrite,
#     973                         c2pread, c2pwrite,
#     974                         errread, errwrite,
#     975                         restore_signals,
#     976                         gid, gids, uid, umask,
#     977                         start_new_session)
#     978 except:
#     979     # Cleanup if the child failed starting.
#
# File ~/miniforge3/envs/forge_webscrap/lib/python3.10/subprocess.py:1845, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1844         err_msg = os.strerror(errno_num)
# -> 1845     raise child_exception_type(errno_num, err_msg, err_filename)
#    1846 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'msedgedriver'
#
# During handling of the above exception, another exception occurred:
#
# WebDriverException                        Traceback (most recent call last)
# /Users/eduardotorres/Documents/GitHub/python-development/webscrappers/google-news/google-bot.ipynb Cell 1 in <cell line: 27>()
#      <a href='vscode-notebook-cell:/Users/eduardotorres/Documents/GitHub/python-development/webscrappers/google-news/google-bot.ipynb#W0sZmlsZQ%3D%3D?line=23'>24</a> print(os.getcwd())
#      <a href='vscode-notebook-cell:/Users/eduardotorres/Documents/GitHub/python-development/webscrappers/google-news/google-bot.ipynb#W0sZmlsZQ%3D%3D?line=25'>26</a> executable_chrome = ''.join([add_ins, sl, r'chromedriver'])
# ---> <a href='vscode-notebook-cell:/Users/eduardotorres/Documents/GitHub/python-development/webscrappers/google-news/google-bot.ipynb#W0sZmlsZQ%3D%3D?line=26'>27</a> driver = webdriver.Chrome(service = service, options=options, executable_path=executable_chrome)
#      <a href='vscode-notebook-cell:/Users/eduardotorres/Documents/GitHub/python-development/webscrappers/google-news/google-bot.ipynb#W0sZmlsZQ%3D%3D?line=28'>29</a> def chatbot_response(query):
#      <a href='vscode-notebook-cell:/Users/eduardotorres/Documents/GitHub/python-development/webscrappers/google-news/google-bot.ipynb#W0sZmlsZQ%3D%3D?line=29'>30</a>     try:
#
# File ~/miniforge3/envs/forge_webscrap/lib/python3.10/site-packages/selenium/webdriver/chrome/webdriver.py:69, in WebDriver.__init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      66 if not service:
#      67     service = Service(executable_path, port, service_args, service_log_path)
# ---> 69 super().__init__(DesiredCapabilities.CHROME['browserName'], "goog",
#      70                  port, options,
#      71                  service_args, desired_capabilities,
#      72                  service_log_path, service, keep_alive)
#
# File ~/miniforge3/envs/forge_webscrap/lib/python3.10/site-packages/selenium/webdriver/chromium/webdriver.py:89, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, port, options, service_args, desired_capabilities, service_log_path, service, keep_alive)
#      86     raise AttributeError('service cannot be None')
#      88 self.service = service
# ---> 89 self.service.start()
#      91 try:
#      92     super().__init__(
#      93         command_executor=ChromiumRemoteConnection(
#      94             remote_server_addr=self.service.service_url,
#      95             browser_name=browser_name, vendor_prefix=vendor_prefix,
#      96             keep_alive=keep_alive, ignore_proxy=_ignore_proxy),
#      97         options=options)
#
# File ~/miniforge3/envs/forge_webscrap/lib/python3.10/site-packages/selenium/webdriver/common/service.py:81, in Service.start(self)
#      79 except OSError as err:
#      80     if err.errno == errno.ENOENT:
# ---> 81         raise WebDriverException(
#      82             "'{}' executable needs to be in PATH. {}".format(
#      83                 os.path.basename(self.path), self.start_error_message)
#      84         )
#      85     elif err.errno == errno.EACCES:
#      86         raise WebDriverException(
#      87             "'{}' executable may have wrong permissions. {}".format(
#      88                 os.path.basename(self.path), self.start_error_message)
#      89         )
#
# WebDriverException: Message: 'msedgedriver' executable needs to be in PATH. Please download from https://developer.microsoft.com/en-us/microsoft-edge/tools/webdriver/

# %%
#Creating GUI with tkinter
import tkinter
from tkinter import *

def send():
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)
    if msg != '':
        ChatLog.config(state=NORMAL)
        
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#442265", font=("Verdana", 12 ))
        
        res = chatbot_response(msg)
        ChatLog.insert(END, "Bot: " + res + '\n\n')
        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)

base = Tk()
base.title("Googlebot")
base.geometry("400x500")
base.resizable(width=FALSE, height=FALSE)

#Create Chat window
ChatLog = Text(base, bd=0, bg="white", height="8", width="50", font="Arial",)
ChatLog.config(state=DISABLED)

#Bind scrollbar to Chat window
scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set

#Create Button to send message
SendButton = Button(base, font=("Verdana",12,'bold'), text="Send", width="12", height=5,
                    bd=0, bg="#32de97", activebackground="#3c9d9b",fg='#ffffff',
                    command= send )

#Create the box to enter message
EntryBox = Text(base, bd=0, bg="white",width="29", height="5", font="Arial")

#EntryBox.bind("<Return>", send)
#Place all components on the screen
scrollbar.place(x=376,y=6, height=386)
ChatLog.place(x=6,y=6, height=386, width=370)
EntryBox.place(x=128, y=401, height=90, width=265)
SendButton.place(x=6, y=401, height=90)
base.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\daniel.torres\AppData\Local\Temp\ipykernel_12028\1678448463.py", line 26, in chatbot_response
#     content = driver.find_element(by=By.CLASS_NAME,value="xpdopen").get_attribute("innerText")
#   File "c:\ProgramData\Anaconda3\envs\mybot\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 856, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "c:\ProgramData\Anaconda3\envs\mybot\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 429, in execute
#     self.error_handler.check_response(response)
#   File "c:\ProgramData\Anaconda3\envs\mybot\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 243, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":".xpdopen"}
#   (Session info: headless MicrosoftEdge=106.0.1370.47)
# Stacktrace:
# Backtrace:
# 	Microsoft::Applications::Events::EventProperties::unpack [0x006A7AF3+60003]
# 	Microsoft::Applications::Events::ISemanticContext::SetTicket [0x0059ECD1+712001]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x0042D3AE+4190]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x00457E19+99481]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x00457FBB+99899]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x0047EA12+258194]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x0046CAC4+184644]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x0047D2C5+252229]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x0046C7F6+183926]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x0044F5B9+64569]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x004502EF+67951]
# 	Microsoft::Applications::Events::ILogManager::DispatchEventBroadcast [0x008BB925+714101]
# 	Microsoft::Applications::Events::ILogManager::DispatchEventBroadcast [0x0082CFEC+130108]
# 	Microsoft::Applications::Events::ILogManager::DispatchEventBroadcast [0x0082C97A+128458]
# 	Microsoft::Applications::Events::ILogManager::DispatchEventBroadcast [0x0083069B+144107]
# 	Microsoft::Applications::Events::ILogManager::DispatchEventBroadcast [0x0082D8B3+132355]
# 	Microsoft::Applications::Events::ISemanticContext::SetTicket [0x005B10EB+786779]
# 	Microsoft::Applications::Events::ISemanticContext::SetTicket [0x005BBE98+831240]
# 	Microsoft::Applications::Events::ISemanticContext::SetTicket [0x005BC024+831636]
# 	Microsoft::Applications::Events::ISemanticContext::SetTicket [0x005CE324+906132]
# 	BaseThreadInitThunk [0x7591FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x775E7C3E+286]
# 	RtlGetAppContainerNamedObjectPath [0x775E7C0E+238]
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\daniel.torres\AppData\Local\Temp\ipykernel_12028\1678448463.py", line 36, in chatbot_response
#     response = driver.find_element(By.ID,"mntl-sc-block_1-0-1").get_attribute("innerText")
#   File "c:\ProgramData\Anaconda3\envs\mybot\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 856, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "c:\ProgramData\Anaconda3\envs\mybot\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 429, in execute
#     self.error_handler.check_response(response)
#   File "c:\ProgramData\Anaconda3\envs\mybot\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 243, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="mntl-sc-block_1-0-1"]"}
#   (Session info: headless MicrosoftEdge=106.0.1370.47)
# Stacktrace:
# Backtrace:
# 	Microsoft::Applications::Events::EventProperties::unpack [0x006A7AF3+60003]
# 	Microsoft::Applications::Events::ISemanticContext::SetTicket [0x0059ECD1+712001]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x0042D3AE+4190]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x00457E19+99481]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x00457FBB+99899]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x0047EA12+258194]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x0046CAC4+184644]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x0047D2C5+252229]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x0046C7F6+183926]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x0044F5B9+64569]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x004502EF+67951]
# 	Microsoft::Applications::Events::ILogManager::DispatchEventBroadcast [0x008BB925+714101]
# 	Microsoft::Applications::Events::ILogManager::DispatchEventBroadcast [0x0082CFEC+130108]
# 	Microsoft::Applications::Events::ILogManager::DispatchEventBroadcast [0x0082C97A+128458]
# 	Microsoft::Applications::Events::ILogManager::DispatchEventBroadcast [0x0083069B+144107]
# 	Microsoft::Applications::Events::ILogManager::DispatchEventBroadcast [0x0082D8B3+132355]
# 	Microsoft::Applications::Events::ISemanticContext::SetTicket [0x005B10EB+786779]
# 	Microsoft::Applications::Events::ISemanticContext::SetTicket [0x005BBE98+831240]
# 	Microsoft::Applications::Events::ISemanticContext::SetTicket [0x005BC024+831636]
# 	Microsoft::Applications::Events::ISemanticContext::SetTicket [0x005CE324+906132]
# 	BaseThreadInitThunk [0x7591FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x775E7C3E+286]
# 	RtlGetAppContainerNamedObjectPath [0x775E7C0E+238]
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\ProgramData\Anaconda3\envs\mybot\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "c:\ProgramData\Anaconda3\envs\mybot\lib\site-packages\urllib3\connectionpool.py", line 386, in _make_request
#     self._validate_conn(conn)
#   File "c:\ProgramData\Anaconda3\envs\mybot\lib\site-packages\urllib3\connectionpool.py", line 1042, in _validate_conn
#     conn.connect()
#   File "c:\ProgramData\Anaconda3\envs\mybot\lib\site-packages\urllib3\connection.py", line 414, in connect
#     self.sock = ssl_wrap_socket(
#   File "c:\ProgramData\Anaconda3\envs\mybot\lib\site-packages\urllib3\util\ssl_.py", line 449, in ssl_wrap_socket
#     ssl_sock = _ssl_wrap_socket_impl(
#   File "c:\ProgramData\Anaconda3\envs\mybot\lib\site-packages\urllib3\util\ssl_.py", line 493, in _ssl_wrap_socket_impl
#     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#   File "c:\ProgramData\Anaconda3\envs\mybot\lib\ssl.py", line 500, in wrap_socket
#     return self.sslsocket_class._create(
#   File "c:\ProgramData\Anaconda3\envs\mybot\lib\ssl.py", line 1040, in _create
#     self.do_handshake()
#   File "c:\ProgramData\Anaconda3\envs\mybot\lib\ssl.py", line 1309, in do_handshake
#     self._sslobj.do_handshake()
# ssl.SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate in certificate chain (_ssl.c:1131)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\ProgramData\Anaconda3\envs\mybot\lib\site-packages\requests\adapters.py", line 489, in send
#     resp = conn.urlopen(
#   File "c:\ProgramData\Anaconda3\envs\mybot\lib\site-packages\urllib3\connectionpool.py", line 787, in urlopen
#     retries = retries.increment(
#   File "c:\ProgramData\Anaconda3\envs\mybot\lib\site-packages\urllib3\util\retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='en.wikipedia.org', port=443): Max retries exceeded with url: /w/api.php?action=query&format=json&limit=10&list=search&srlimit=10&srprop=&srsearch=you (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate in certificate chain (_ssl.c:1131)')))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\ProgramData\Anaconda3\envs\mybot\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\Users\daniel.torres\AppData\Local\Temp\ipykernel_12028\1278321295.py", line 14, in send
#     res = chatbot_response(msg)
#   File "C:\Users\daniel.torres\AppData\Local\Temp\ipykernel_12028\1678448463.py", line 43, in chatbot_response
#     mercury = wikipedia.summary(wikipedia.search(query)[0], auto_suggest=False)
#   File "c:\ProgramData\Anaconda3\envs\mybot\lib\site-packages\wikipedia\util.py", line 28, in __call__
#     ret = self._cache[key] = self.fn(*args, **kwargs)
#   File "c:\ProgramData\Anaconda3\envs\mybot\lib\site-packages\wikipedia\wikipedia.py", line 103, in search
#     raw_results = _wiki_request(search_params)
#   File "c:\ProgramData\Anaconda3\envs\mybot\lib\site-packages\wikipedia\wikipedia.py", line 737, in _wiki_request
#     r = requests.get(API_URL, params=params, headers=headers)
#   File "c:\ProgramData\Anaconda3\envs\mybot\lib\site-packages\requests\api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "c:\ProgramData\Anaconda3\envs\mybot\lib\site-packages\requests\api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "c:\ProgramData\Anaconda3\envs\mybot\lib\site-packages\requests\sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "c:\ProgramData\Anaconda3\envs\mybot\lib\site-packages\requests\sessions.py", line 723, in send
#     history = [resp for resp in gen]
#   File "c:\ProgramData\Anaconda3\envs\mybot\lib\site-packages\requests\sessions.py", line 723, in <listcomp>
#     history = [resp for resp in gen]
#   File "c:\ProgramData\Anaconda3\envs\mybot\lib\site-packages\requests\sessions.py", line 266, in resolve_redirects
#     resp = self.send(
#   File "c:\ProgramData\Anaconda3\envs\mybot\lib\site-packages\requests\sessions.py", line 701, in send
#     r = adapter.send(request, **kwargs)
#   File "c:\ProgramData\Anaconda3\envs\mybot\lib\site-packages\requests\adapters.py", line 563, in send
#     raise SSLError(e, request=request)
# requests.exceptions.SSLError: HTTPSConnectionPool(host='en.wikipedia.org', port=443): Max retries exceeded with url: /w/api.php?action=query&format=json&limit=10&list=search&srlimit=10&srprop=&srsearch=you (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate in certificate chain (_ssl.c:1131)')))
